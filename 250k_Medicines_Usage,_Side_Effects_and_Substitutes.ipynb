# %% [markdown]
# <a href="https://colab.research.google.com/github/snigybee/IBMPROJ6/blob/main/250k_Medicines_Usage%2C_Side_Effects_and_Substitutes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# prompt: drop duplicate rows based on certain columns

# Assuming you have a DataFrame named 'df'
df = df.drop_duplicates(subset=['column1', 'column2'], keep='first')
# Replace 'column1', 'column2' with the actual column names you want to consider for duplicates
# keep='first' keeps the first occurrence and drops the rest. You can change it to 'last' or False as needed.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-83328300f64c> in <cell line: 4>()
#       2
#       3 # Assuming you have a DataFrame named 'df'
# ----> 4 df = df.drop_duplicates(subset=['column1', 'column2'], keep='first')
#       5 # Replace 'column1', 'column2' with the actual column names you want to consider for duplicates
#       6 # keep='first' keeps the first occurrence and drops the rest. You can change it to 'last' or False as needed.
#
# NameError: name 'df' is not defined

# %%
# Reading the csv file
df1 = pd.read_csv('250k Medicines Usage, Side Effects and Substitutes.csv')

# dropping duplicate rows with same drug name
df1 = df1.drop_duplicates(subset=['name'])
# Out:
# <ipython-input-63-9b5da550e170>:2: DtypeWarning: Columns (42,43,44,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('250k Medicines Usage, Side Effects and Substitutes.csv')

# %%
# Printing the unique number of drugs in the dataset
print(f"Unique number of drugs in the dataset : {len(df1[['id','name']].drop_duplicates())}")
print(f"Unique number of drugs in the dataset : {len(df1[['name']].drop_duplicates())}")
# Out:
# Unique number of drugs in the dataset : 222825
# Unique number of drugs in the dataset : 222825

# %%
# Out:
#                                                   index         0
# 0                                                Nausea  140919.0
# 1                                              Diarrhea  124933.0
# 2                                              Vomiting   89867.0
# 3                                              Headache   89630.0
# 4                                             Dizziness   65993.0
# ...                                                 ...       ...
# 1049                 Calcification due to extravasation       1.0
# 1050                                   Throat infection       1.0
# 1051                                   Calcinosis cutis       1.0
# 1052                                     Cardiac arrest       1.0
# 1053  Prolonged activated partial thromboplastin tim...       1.0
#
# [1054 rows x 2 columns]

# %%
df1['num_substitutes'] = df1[['substitute0', 'substitute1','substitute2', 'substitute3','substitute4']].notnull().sum(axis=1)

sideeffectscols = [f'sideEffect{i}' for i in range(42)]

side_effects = df1[sideeffectscols].apply(lambda x: x.value_counts()).sum(axis=1).sort_values(ascending=False)
print(side_effects.head(10))

print(f'\n')

use_columns = [f'use{i}' for i in range(5)]
uses = df1[use_columns].apply(lambda x: x.value_counts()).sum(axis=1).sort_values(ascending=False)

# Display the top 10 most common uses
print(uses.head(10))
# Out:
# Nausea              140919.0
# Diarrhea            124933.0
# Vomiting             89867.0
# Headache             89630.0
# Dizziness            65993.0
# Stomach pain         45555.0
# Rash                 31651.0
# Dryness in mouth     31098.0
# Sleepiness           30608.0
# Flatulence           28823.0
# dtype: float64
#
#
# Treatment of Bacterial infections                             36867.0
#  Pain relief                                                  21083.0
# Treatment of Peptic ulcer disease                             12534.0
# Treatment of Gastroesophageal reflux disease (Acid reflux)    12517.0
# Treatment of Type 2 diabetes mellitus                         10191.0
#  Bacterial infections                                          9667.0
# Treatment of Hypertension (high blood pressure)                7141.0
# Treatment of Allergic conditions                               5727.0
# Treatment of Sneezing and runny nose due to allergies          4893.0
# ...

# %%
chemical_class_effects = df1.groupby('Chemical Class')[[side_effects_columns].apply(lambda x: x.notnull().sum()).sum(axis=1)

# Display the top 10 Chemical Classes with the most side effects
print(chemical_class_effects.sort_values(ascending=False).head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d120aac26de2> in <cell line: 1>()
# ----> 1 chemical_class_effects = df1.groupby('Chemical Class')[uses].apply(lambda x: x.notnull().sum()).sum(axis=1)
#       2
#       3 # Display the top 10 Chemical Classes with the most side effects
#       4 print(chemical_class_effects.sort_values(ascending=False).head(10))
#
# NameError: name 'df1' is not defined

# %%
df1.columns
# Out:
# Index(['id', 'name', 'substitute0', 'substitute1', 'substitute2',
#        'substitute3', 'substitute4', 'sideEffect0', 'sideEffect1',
#        'sideEffect2', 'sideEffect3', 'sideEffect4', 'sideEffect5',
#        'sideEffect6', 'sideEffect7', 'sideEffect8', 'sideEffect9',
#        'sideEffect10', 'sideEffect11', 'sideEffect12', 'sideEffect13',
#        'sideEffect14', 'sideEffect15', 'sideEffect16', 'sideEffect17',
#        'sideEffect18', 'sideEffect19', 'sideEffect20', 'sideEffect21',
#        'sideEffect22', 'sideEffect23', 'sideEffect24', 'sideEffect25',
#        'sideEffect26', 'sideEffect27', 'sideEffect28', 'sideEffect29',
#        'sideEffect30', 'sideEffect31', 'sideEffect32', 'sideEffect33',
#        'sideEffect34', 'sideEffect35', 'sideEffect36', 'sideEffect37',
#        'sideEffect38', 'sideEffect39', 'sideEffect40', 'sideEffect41', 'use0',
#        'use1', 'use2', 'use3', 'use4', 'Chemical Class', 'Habit Forming',
# ...

# %%
union_arr = df1['sideEffect0'].unique()

for i in range(1,42):
  sideeffect_string = f"sideEffect{i}"
  arr1 = df1[sideeffect_string].unique()
  union_arr = list(set(union_arr) | set(arr1))

print(f"Total number of unique side effects in the dataset : {len(union_arr)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4b17b29109f0> in <cell line: 1>()
# ----> 1 union_arr = df1['sideEffect0'].unique()
#       2
#       3 for i in range(1,42):
#       4   sideeffect_string = f"sideEffect{i}"
#       5   arr1 = df1[sideeffect_string].unique()
#
# NameError: name 'df1' is not defined

# %%
union_arr = df1['use0'].unique()

for i in range(1,5):
  uses_string = f"use{i}"
  arr1 = df1[uses_string].unique()
  union_arr = list(set(union_arr) | set(arr1))

print(f"Total number of unique uses in the dataset : {len(union_arr)}")
# Out:
# Total number of unique uses in the dataset : 710

# %%
print(f"Total number of unique drugs in the dataset : {len(df1['id'].unique())}")
# Out:
# Total number of unique drugs in the dataset : 90015

# %%
## Number of Drugs with Habit forming effect : 2563,
## Rest 87,451 drugs are not habit forming
df1['Habit Forming'].value_counts()
# Out:
# Habit Forming
# No     87451
# Yes     2563
# Name: count, dtype: int64

# %%
print(f"Total number of Therapeutic Classes in the dataset : {len(df1['Therapeutic Class'].unique())}")
print(f"Total number of Action Classes in the dataset : {len(df1['Action Class'].unique())}")
print(f"Total number of Chemical Classes in the dataset : {len(df1['Chemical Class'].unique())}")
# Out:
# Total number of Therapeutic Classes in the dataset : 23
# Total number of Action Classes in the dataset : 378
# Total number of Chemical Classes in the dataset : 680

# %%
df1['Therapeutic Class'].value_counts()
# Out:
# Therapeutic Class
# ANTI INFECTIVES                26102
# PAIN ANALGESICS                13251
# GASTRO INTESTINAL               9073
# RESPIRATORY                     8733
# NEURO CNS                       8114
# CARDIAC                         6785
# DERMA                           3218
# OPHTHAL                         2578
# HORMONES                        2562
# ANTI DIABETIC                   2112
# VITAMINS MINERALS NUTRIENTS     1624
# ANTI NEOPLASTICS                1319
# GYNAECOLOGICAL                  1155
# BLOOD RELATED                   1083
# ANTI MALARIALS                   758
# UROLOGY                          542
# OPHTHAL OTOLOGICALS              380
# OTOLOGICALS                      189
# SEX STIMULANTS REJUVENATORS      185
# OTHERS                           112
# VACCINES                          73
# STOMATOLOGICALS                   45
# Name: count, dtype: int64

# %%
df1['Action Class'].value_counts()
# Out:
# Action Class
# Cephalosporins: 3 generation                                                       6136
# Macrolides                                                                         3885
# Glucocorticoids                                                                    2452
# Quinolones/ Fluroquinolones                                                        1842
# NSAID's- Non-Selective COX 1&2 Inhibitors (acetic acid)                            1498
#                                                                                    ...
# Respiratory stimulant                                                                 1
# Ion exchange resins (Potassium Binders)                                               1
# Protease inhibitors- Pancreatitis                                                     1
# Thromboxane A2/prostaglandin endoperoxide receptor antagonist- Bronchial asthma       1
# ...

# %%
# Checking number of chemical classes that exist in the dataset
df1['Chemical Class'].value_counts()
# Out:
# Chemical Class
# Fluoroquinolone                                              7929
# Broad Spectrum (Third & fourth generation cephalosporins)    7402
# Macrolides                                                   5604
# Sulfinylbenzimidazole Derivative                             4871
# Broad spectrum (Third & fourth generation cephalosporins}    4492
#                                                              ...
# Phenylimidazoles                                                1
# Testosterone derivative                                         1
# Alkaline Earth Metal Chloride                                   1
# Pantothenic acid Derivative                                     1
# Oxazole Propionic Acid Derivative                               1
# Name: count, Length: 872, dtype: int64

# %%
df1.columns
# Out:
# Index(['id', 'name', 'substitute0', 'substitute1', 'substitute2',
#        'substitute3', 'substitute4', 'sideEffect0', 'sideEffect1',
#        'sideEffect2', 'sideEffect3', 'sideEffect4', 'sideEffect5',
#        'sideEffect6', 'sideEffect7', 'sideEffect8', 'sideEffect9',
#        'sideEffect10', 'sideEffect11', 'sideEffect12', 'sideEffect13',
#        'sideEffect14', 'sideEffect15', 'sideEffect16', 'sideEffect17',
#        'sideEffect18', 'sideEffect19', 'sideEffect20', 'sideEffect21',
#        'sideEffect22', 'sideEffect23', 'sideEffect24', 'sideEffect25',
#        'sideEffect26', 'sideEffect27', 'sideEffect28', 'sideEffect29',
#        'sideEffect30', 'sideEffect31', 'sideEffect32', 'sideEffect33',
#        'sideEffect34', 'sideEffect35', 'sideEffect36', 'sideEffect37',
#        'sideEffect38', 'sideEffect39', 'sideEffect40', 'sideEffect41', 'use0',
#        'use1', 'use2', 'use3', 'use4', 'Chemical Class', 'Habit Forming',
# ...

# %%
print(f"Total number of unique medicines in the dataset : {len(df1['id'].unique())}")
# Out:
# Total number of unique medicines in the dataset : 90015

# %%
 df1['num_substitutes'] = df1[['substitute0', 'substitute1','substitute2', 'substitute3','substitute4']].notnull().sum(axis=1)
 df1['num_side_effects'] = df1[['sideEffect0', 'sideEffect1',
       'sideEffect2', 'sideEffect3', 'sideEffect4', 'sideEffect5',
       'sideEffect6', 'sideEffect7', 'sideEffect8', 'sideEffect9',
       'sideEffect10', 'sideEffect11', 'sideEffect12', 'sideEffect13',
       'sideEffect14', 'sideEffect15', 'sideEffect16', 'sideEffect17',
       'sideEffect18', 'sideEffect19', 'sideEffect20', 'sideEffect21',
       'sideEffect22', 'sideEffect23', 'sideEffect24', 'sideEffect25',
       'sideEffect26', 'sideEffect27', 'sideEffect28', 'sideEffect29',
       'sideEffect30', 'sideEffect31', 'sideEffect32', 'sideEffect33',
       'sideEffect34', 'sideEffect35', 'sideEffect36', 'sideEffect37',
       'sideEffect38', 'sideEffect39', 'sideEffect40', 'sideEffect41']].notnull().sum(axis=1)

# %%
df1.sort_values(by='num_substitutes',ascending=False)
# Out:
#             id                              name  \
# 0            1          augmentin 625 duo tablet
# 160951  160952  nidagen 200 soft gelatin capsule
# 160953  160954                    nixiper lotion
# 160955  160956             novegrow 10% solution
# 160957  160958                  nemdaa 10 tablet
# ...        ...                               ...
# 43158    43159               cilforth 5mg tablet
# 94739    94740             forglyn plus respicap
# 6598      6599                asthelite pd syrup
# 43168    43169                cloam 0.5mg tablet
# 194519  194520                prolide 5mg tablet
#
#                              substitute0              substitute1  \
# 0         Penciclav 500 mg/125 mg Tablet   Moxikind-CV 625 Tablet
# 160951  Uterone 200 Soft Gelatin Capsule     Endogest 200 Capsule
# 160953                  Permetron Lotion          Scabenil Lotion
# 160955         Trichodense  10% Solution  Fultress-F 10% Solution
# ...

# %%
df1.sort_values(by='num_side_effects',ascending=False)
# Out:
#             id                           name  \
# 30832    30833            balila 25mg capsule
# 30664    30665                 balila capsule
# 61995    61996    cyfalo o 200mg/200mg tablet
# 62411    62412  cefibook o 200mg/200mg tablet
# 62379    62380               cefikab-o tablet
# ...        ...                            ...
# 125315  125316                    krizal soap
# 125319  125320                       kent gel
# 39943    39944           cynocal-16 injection
# 39939    39940               cilamet xl 20/50
# 211604  211605            sepsadone 2% gargle
#
#                             substitute0         substitute1  \
# 30832                               NaN                 NaN
# 30664                               NaN                 NaN
# 61995   Hifen Plus 200 mg/200 mg Tablet    Omcef 200 Tablet
# 62411   Hifen Plus 200 mg/200 mg Tablet    Omcef 200 Tablet
# 62379   Hifen Plus 200 mg/200 mg Tablet    Omcef 200 Tablet
# ...

# %%
df1.iloc[0]
# Out:
# id                                                   1
# name                          augmentin 625 duo tablet
# substitute0             Penciclav 500 mg/125 mg Tablet
# substitute1                     Moxikind-CV 625 Tablet
# substitute2                    Moxiforce-CV 625 Tablet
# substitute3                         Fightox 625 Tablet
# substitute4                    Novamox CV 625mg Tablet
# sideEffect0                                   Vomiting
# sideEffect1                                     Nausea
# sideEffect2                                   Diarrhea
# sideEffect3                                        NaN
# sideEffect4                                        NaN
# sideEffect5                                        NaN
# sideEffect6                                        NaN
# sideEffect7                                        NaN
# sideEffect8                                        NaN
# sideEffect9                                        NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d241540b5a5a> in <cell line: 1>()
# ----> 1 missing_vals = df.isnull().sum() / len(df)
#       2 print(missing_vals)
#
# NameError: name 'df' is not defined

# %%
 import pandas as pd

# %%
from typing import ClassVar
df=pd.read_csv('/content/250k Medicines Usage, Side Effects and Substitutes (1).csv')
df
# Out:
# <ipython-input-5-83c0fae589e0>:2: DtypeWarning: Columns (42,43,44,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/250k Medicines Usage, Side Effects and Substitutes (1).csv')
#             id                              name  \
# 0            1          augmentin 625 duo tablet
# 1            2               azithral 500 tablet
# 2            3                  ascoril ls syrup
# 3            4              allegra 120mg tablet
# 4            5                    avil 25 tablet
# ...        ...                               ...
# 184112  184113                  ometic injection
# 184113  184114              omipace 20mg capsule
# 184114  184115                    ond 4mg tablet
# 184115  184116  omna xp 500 mg/62.5 mg injection
# 184116  184117            oltaur 50mg suspension
#
#                              substitute0                    substitute1  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'substitute0', 'substitute1', 'substitute2',
#        'substitute3', 'substitute4', 'sideEffect0', 'sideEffect1',
#        'sideEffect2', 'sideEffect3', 'sideEffect4', 'sideEffect5',
#        'sideEffect6', 'sideEffect7', 'sideEffect8', 'sideEffect9',
#        'sideEffect10', 'sideEffect11', 'sideEffect12', 'sideEffect13',
#        'sideEffect14', 'sideEffect15', 'sideEffect16', 'sideEffect17',
#        'sideEffect18', 'sideEffect19', 'sideEffect20', 'sideEffect21',
#        'sideEffect22', 'sideEffect23', 'sideEffect24', 'sideEffect25',
#        'sideEffect26', 'sideEffect27', 'sideEffect28', 'sideEffect29',
#        'sideEffect30', 'sideEffect31', 'sideEffect32', 'sideEffect33',
#        'sideEffect34', 'sideEffect35', 'sideEffect36', 'sideEffect37',
#        'sideEffect38', 'sideEffect39', 'sideEffect40', 'sideEffect41', 'use0',
#        'use1', 'use2', 'use3', 'use4', 'Chemical Class', 'Habit Forming',
#        'Therapeutic Class', 'Action Class'],
# ...

# %%
df.shape
# Out:
# (184117, 58)

# %%
missing_vals=df.isnull().sum()
missing_vals
# Out:
# id                        0
# name                      0
# substitute0            6913
# substitute1           10345
# substitute2           12978
# substitute3           15435
# substitute4           17468
# sideEffect0               1
# sideEffect1            7179
# sideEffect2           14160
# sideEffect3           31009
# sideEffect4           65156
# sideEffect5           90338
# sideEffect6          118929
# sideEffect7          135254
# sideEffect8          148440
# sideEffect9          156502
# sideEffect10         163891
# sideEffect11         169223
# sideEffect12         172227
# sideEffect13         173346
# sideEffect14         176524
# sideEffect15         178331
# sideEffect16         179691
# sideEffect17         180142
# sideEffect18         180743
# sideEffect19         181191
# sideEffect20         181674
# sideEffect21         181749
# sideEffect22         181805
# sideEffect23         181911
# sideEffect24         182056
# sideEffect25         183028
# ...

# %%
 missing_more_15 = missing_vals[missing_vals > 0.15]
 missing_more_15
# Out:
# substitute0            6913
# substitute1           10345
# substitute2           12978
# substitute3           15435
# substitute4           17468
# sideEffect0               1
# sideEffect1            7179
# sideEffect2           14160
# sideEffect3           31009
# sideEffect4           65156
# sideEffect5           90338
# sideEffect6          118929
# sideEffect7          135254
# sideEffect8          148440
# sideEffect9          156502
# sideEffect10         163891
# sideEffect11         169223
# sideEffect12         172227
# sideEffect13         173346
# sideEffect14         176524
# sideEffect15         178331
# sideEffect16         179691
# sideEffect17         180142
# sideEffect18         180743
# sideEffect19         181191
# sideEffect20         181674
# sideEffect21         181749
# sideEffect22         181805
# sideEffect23         181911
# sideEffect24         182056
# sideEffect25         183028
# sideEffect26         183028
# sideEffect27         183033
# ...

# %%
 list(missing_more_15.index)
# Out:
# ['substitute0',
#  'substitute1',
#  'substitute2',
#  'substitute3',
#  'substitute4',
#  'sideEffect0',
#  'sideEffect1',
#  'sideEffect2',
#  'sideEffect3',
#  'sideEffect4',
#  'sideEffect5',
#  'sideEffect6',
#  'sideEffect7',
#  'sideEffect8',
#  'sideEffect9',
#  'sideEffect10',
#  'sideEffect11',
#  'sideEffect12',
#  'sideEffect13',
#  'sideEffect14',
#  'sideEffect15',
#  'sideEffect16',
#  'sideEffect17',
#  'sideEffect18',
#  'sideEffect19',
#  'sideEffect20',
#  'sideEffect21',
#  'sideEffect22',
#  'sideEffect23',
#  'sideEffect24',
#  'sideEffect25',
#  'sideEffect26',
#  'sideEffect27',
#  'sideEffect28',
#  'sideEffect29',
#  'sideEffect30',
#  'sideEffect31',
#  'sideEffect32',
#  'sideEffect33',
#  'sideEffect34',
#  'sideEffect35',
#  'sideEffect36',
#  'sideEffect37',
#  'sideEffect38',
#  'sideEffect39',
#  'sideEffect40',
#  'sideEffect41',
#  'use0',
#  'use1',
#  'use2',
#  'use3',
#  'use4',
#  'Chemical Class',
#  'Habit Forming',
#  'Therapeutic Class',
# ...

# %%
 missing_vals[missing_vals <= 0.15]
# Out:
# id      0
# name    0
# dtype: int64

# %%
df1 = df.drop(list(missing_more_15.index) , axis = 'columns')
df1.head()
# Out:
#    id                      name
# 0   1  augmentin 625 duo tablet
# 1   2       azithral 500 tablet
# 2   3          ascoril ls syrup
# 3   4      allegra 120mg tablet
# 4   5            avil 25 tablet

# %%
 df1 = df1.drop_duplicates()
